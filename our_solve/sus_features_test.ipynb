# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('train.csv')
df.info()
# Out:
# C:\Users\misha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279792 entries, 0 to 279791
# Data columns (total 77 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   city                                 279792 non-null  object
#  1   floor                                103555 non-null  object
#  2   id                                   279792 non-null  object
#  3   lat                                  279792 non-null  float64
#  4   lng                                  279792 non-null  float64
#  5   osm_amenity_points_in_0.001          279792 non-null  int64
#  6   osm_amenity_points_in_0.005          279792 non-null  int64
# ...

# %%
from typing import List

def get_group_of_columns(df: pd.DataFrame, substrings: List[str]) -> List[pd.DataFrame]:
    groups = []
    for sub in substrings:
        groups.append(df.loc[:, df.columns.intersection([key for key in df if sub in key])])
    return groups

def check_feature(substrings, feature):
    for sub in substrings:
        if sub in feature:
            return 0
    return 1

# %%
df_categoria
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d08776aa0848> in <module>
# ----> 1 df_categoria
#
# NameError: name 'df_categoria' is not defined

# %%
df_categorial = df.select_dtypes(include=[object])
substrings = ['osm', 'reform']
df_osm, df_reform = get_group_of_columns(df, substrings)


few_df2= df.select_dtypes(include=['int64', 'float64'])
few_df = df.drop([feature for feature in df if not check_feature(substrings, feature)], 1).select_dtypes(exclude=[object])

# %%
few_df2
# Out:
#               lat        lng  osm_amenity_points_in_0.001  \
# 0       57.998207  56.292797                            4
# 1       55.574284  39.543835                            3
# 2       57.619140  39.850525                            1
# 3       53.897083  87.108604                            0
# 4       55.802590  37.487110                            1
# ...           ...        ...                          ...
# 279787  56.459183  84.979334                            2
# 279788  59.936954  30.356383                           10
# 279789  54.729233  20.514968                            0
# 279790  55.360680  86.081460                            5
# 279791  58.592915  49.677439                            1
#
#         osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                                19                            35
# 1                                24                            37
# 2                                30                            67
# ...

# %%
df.price_type.value_counts()
# Out:
# 0    275299
# 1      4493
# Name: price_type, dtype: int64

# %%
import matplotlib.pyplot as plt
from numpy import log1p

df_osm.drop('osm_city_nearest_name', 1).apply(log1p).hist(figsize=(30, 30), bins=20)
plt.show()

# %%
coords = df.iloc[:, 3:5]
coords
# Out:
#               lat        lng
# 0       57.998207  56.292797
# 1       55.574284  39.543835
# 2       57.619140  39.850525
# 3       53.897083  87.108604
# 4       55.802590  37.487110
# ...           ...        ...
# 279787  56.459183  84.979334
# 279788  59.936954  30.356383
# 279789  54.729233  20.514968
# 279790  55.360680  86.081460
# 279791  58.592915  49.677439
#
# [279792 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
    

X_train, X_test, y_train, y_test = train_test_split(df_num.dropna().drop('per_square_meter_price', 1), df_num['per_square_meter_price'], test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4b88d72a60c4> in <module>
#       2
#       3
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(df_num.dropna().drop('per_square_meter_price', 1), df_num['per_square_meter_price'], test_size=0.33, random_state=42)
#
# NameError: name 'df_num' is not defined

# %%
from geopy.geocoders import Nominatim
from geopy import distance

geolocator = Nominatim(user_agent="example app")

# %%
df['city'][0]

# %%
i = 0
geolocator.geocode(f"{df['city'][i]}, {str(df['region'][i])}, Russia")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e5788d465482> in <module>
#       1 i = 0
# ----> 2 geolocator.geocode(f"{df['city'][i]}, {str(df['region'][i])}, Russia")
#
# NameError: name 'geolocator' is not defined

# %%
coords
# Out:
#               lat        lng
# 0       57.998207  56.292797
# 1       55.574284  39.543835
# 2       57.619140  39.850525
# 3       53.897083  87.108604
# 4       55.802590  37.487110
# ...           ...        ...
# 279787  56.459183  84.979334
# 279788  59.936954  30.356383
# 279789  54.729233  20.514968
# 279790  55.360680  86.081460
# 279791  58.592915  49.677439
#
# [279792 rows x 2 columns]

# %%
distances = get_distances(coords.to_records(index=False).tolist(), df['city'].to_list(), df['region'].to_list())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d24aa9779f35> in <module>
# ----> 1 distances = get_distances(coords.to_records(index=False).tolist(), df['city'].to_list(), df['region'].to_list())
#
# NameError: name 'get_distances' is not defined

# %%
distances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a11e939ba179> in <module>
# ----> 1 distances
#
# NameError: name 'distances' is not defined

# %%
categorial_features = df.select_dtypes(include=[object])

# %%
categorial_features
# Out:
#                    city floor          id osm_city_nearest_name  \
# 0                 Пермь   NaN       COL_0                 Пермь
# 1                Шатура   NaN       COL_1         Орехово-Зуево
# 2             Ярославль   NaN       COL_2             Ярославль
# 3           Новокузнецк   NaN       COL_3           Новокузнецк
# 4                Москва   NaN       COL_4                 Химки
# ...                 ...   ...         ...                   ...
# 279787            Томск   1.0  COL_280111                 Томск
# 279788  Санкт-Петербург   1.0  COL_280479       Санкт-Петербург
# 279789      Калининград   3.0  COL_280518           Калининград
# 279790         Кемерово   1.0  COL_280529              Кемерово
# 279791            Киров   1.0  COL_280637                 Киров
#
#                          region  street        date
# 0                 Пермский край  S27289  2020-01-05
# 1            Московская область  S17052  2020-01-05
# ...

# %%
categorial_features['city'].value_counts()
# Out:
# Москва                                        55996
# Санкт-Петербург                               18906
# Краснодар                                     13009
# Екатеринбург                                   8580
# Новосибирск                                    6753
#                                               ...
# слобода Шапошниковка                              1
# Северск городской округ, Сосновка мкр             1
# Ярославский район, пос. Нагорный                  1
# Уссурийский городской округ, с. Корсаковка        1
# Чамлыкская                                        1
# Name: city, Length: 4948, dtype: int64

# %%
categorial_features['subway_dist'] = df.osm_subway_closest_dist
df_with_new_features = categorial_features
df_with_new_features = df_with_new_features.drop(['floor', 'id'], axis = 1)
# Out:
# C:\Users\misha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_with_new_features['transport_stop_closest_dist'] = df.osm_transport_stop_closest_dist
df_with_new_features['per_square_meter_price'] = df.per_square_meter_price
df_with_new_features
# Out:
#                    city osm_city_nearest_name                   region  \
# 0                 Пермь                 Пермь            Пермский край
# 1                Шатура         Орехово-Зуево       Московская область
# 2             Ярославль             Ярославль      Ярославская область
# 3           Новокузнецк           Новокузнецк      Кемеровская область
# 4                Москва                 Химки                   Москва
# ...                 ...                   ...                      ...
# 279787            Томск                 Томск          Томская область
# 279788  Санкт-Петербург       Санкт-Петербург          Санкт-Петербург
# 279789      Калининград           Калининград  Калининградская область
# 279790         Кемерово              Кемерово      Кемеровская область
# 279791            Киров                 Киров        Кировская область
#
#         street        date  subway_dist  transport_stop_closest_dist  \
# ...

# %%
new_df = df.select_dtypes(include=['int64','float64'])
new_df
# Out:
#               lat        lng  osm_amenity_points_in_0.001  \
# 0       57.998207  56.292797                            4
# 1       55.574284  39.543835                            3
# 2       57.619140  39.850525                            1
# 3       53.897083  87.108604                            0
# 4       55.802590  37.487110                            1
# ...           ...        ...                          ...
# 279787  56.459183  84.979334                            2
# 279788  59.936954  30.356383                           10
# 279789  54.729233  20.514968                            0
# 279790  55.360680  86.081460                            5
# 279791  58.592915  49.677439                            1
#
#         osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                                19                            35
# 1                                24                            37
# 2                                30                            67
# ...

# %%
def make_conj(data, feature1, feature2):
    data[feature1 + ' + ' + feature2] = data[feature1].astype(str) + ' + ' + data[feature2].astype(str)
    return (data)

def make_product(data, feature1, feature2):
    """Вычисление произведения расстояния до метро и transport_stop
        example: make_product(df_with_new_features, 'subway_dist', 'transport_stop_closest_dist')
    """
    data['subway+transport'] = data[[feature1, feature2]].product(axis=1)
    return (data)

#make_conj(df_with_new_features, 'city', 'subway_dist')
df_with_new_features = make_product(new_df, 'osm_subway_closest_dist', 'osm_subway_closest_dist')
# Out:
# C:\Users\misha\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#df_with_new_features = df_with_new_features.drop(['city', 'osm_city_nearest_name', 'region', 'street' ],axis=1)
df_with_new_features
# Out:
#               lat        lng  osm_amenity_points_in_0.001  \
# 0       57.998207  56.292797                            4
# 1       55.574284  39.543835                            3
# 2       57.619140  39.850525                            1
# 3       53.897083  87.108604                            0
# 4       55.802590  37.487110                            1
# ...           ...        ...                          ...
# 279787  56.459183  84.979334                            2
# 279788  59.936954  30.356383                           10
# 279789  54.729233  20.514968                            0
# 279790  55.360680  86.081460                            5
# 279791  58.592915  49.677439                            1
#
#         osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                                19                            35
# 1                                24                            37
# 2                                30                            67
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_with_new_features.dropna().drop('per_square_meter_price', 1), df_with_new_features.dropna()['per_square_meter_price'], test_size=0.33, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
from metrics import metrics_stat

# %%
metrics_stat(reg.predict(X_test), y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-1af32214da21> in <module>
# ----> 1 metrics_stat(reg.predict(X_test), y_test)
#
# ~\Desktop\RaifhackDS\our_solve\metrics.py in metrics_stat(y_true, y_pred)
#      38     rmse = mean_squared_error(y_true, y_pred, squared=False)
#      39     r2 = r2_score(y_true, y_pred)
# ---> 40     raif_metric = deviation_metric(y_true, y_pred)
#      41     return {'mape':mape, 'mdape':mdape, 'rmse': rmse, 'r2': r2, 'raif_metric':raif_metric}
#      42
#
# ~\Desktop\RaifhackDS\our_solve\metrics.py in deviation_metric(y_true, y_pred)
#      28
#      29 def deviation_metric(y_true: np.array, y_pred: np.array) -> float:
# ---> 30     return np.array([deviation_metric_one_sample(y_true[n], y_pred[n]) for n in range(len(y_true))]).mean()
#      31
# ...

# %%
few_df['osm_hotels_points_in_0.005'] = df.osm_hotels_points_in_0.005
# Out:
#   File "<ipython-input-34-c83559da370f>", line 1
#     few_df['osm_hotels_points_in_0.005'] = df.osm_hotels_points_in_0.005
#                                                                        ^
# SyntaxError: invalid syntax

# %%
few_df
# Out:
#               lat        lng  per_square_meter_price  total_square  \
# 0       57.998207  56.292797           139937.500000     32.000000
# 1       55.574284  39.543835            60410.714286    280.000000
# 2       57.619140  39.850525            45164.761264    297.400000
# 3       53.897083  87.108604            28805.263158    190.000000
# 4       55.802590  37.487110            13222.591362     60.200000
# ...           ...        ...                     ...           ...
# 279787  56.459183  84.979334            54278.287605    358.320073
# 279788  59.936954  30.356383           595298.017731    119.637556
# 279789  54.729233  20.514968            35758.847259    312.789725
# 279790  55.360680  86.081460            38755.038322     89.201305
# 279791  58.592915  49.677439            41335.014762    172.855871
#
#         realty_type  price_type
# 0                10           0
# 1                10           0
# 2               110           0
# ...

# %%
import seaborn as sns

# %%
coef = few_df2.drop("per_square_meter_price", axis=1).apply(lambda x: x.corr(few_df.per_square_meter_price))

# %%
imp_coef = coef.sort_values()

# %%
imp_coef[:]
# Out:
# osm_subway_closest_dist          -0.268879
# lng                              -0.222177
# osm_city_closest_dist            -0.135308
# osm_train_stop_closest_dist      -0.124464
# reform_mean_year_building_1000   -0.085270
#                                     ...
# osm_amenity_points_in_0.0075      0.475630
# osm_amenity_points_in_0.01        0.476595
# osm_amenity_points_in_0.005       0.483741
# osm_catering_points_in_0.005      0.489370
# osm_city_nearest_population       0.551891
# Length: 69, dtype: float64

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (16.0, 16.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')
